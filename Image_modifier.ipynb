# %%
import numpy as np
from random import randint
from matplotlib import pyplot as plt
import cv2


src = cv2.imread(r"C:\Users\PICHAU\Downloads\foto.jpeg")
img = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)
 
height, width, colors_chanel = img.shape

red_random_factor = [0, 50]
green_random_factor = [0, 150]
blue_random_factor = [0, 100]

for y in range(0, height):
    for x in range(0, width):
        red = img.item(y, x, 0)
        green = img.item(y, x, 1)
        blue = img.item(y, x, 2)
        
        img.itemset((y, x, 0), red*height/100)
        img.itemset((y, x, 1),  green*width/100)
        img.itemset((y, x, 2),  blue*height/100)

# %%
plt.imshow(img)
